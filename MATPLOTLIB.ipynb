# %% [markdown]
# #matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
y=np.array([5,6,9,12,2])                             #ms=marker size
x=np.array([1,2,3,4,5])                              #lw=line width
plt.plot(y,'*',ms=25)               
plt.show()

# %%
y=np.array([5,6,9,12,2])
x=np.array([1,2,3,4,5])
plt.plot(y,'o',ms=25)
plt.show()

# %%
y=np.array([5,6,9,12,2])
x=np.array([1,2,3,4,5])              #:=dotted line
plt.plot(y,'s:m',ms=25)
plt.show()

# %%
y=np.array([5,6,9,12,2])
x=np.array([1,2,3,4,5])                    #-=line
plt.plot(y,'s-m',ms=25)
plt.show()

# %%
y=np.array([5,6,9,12,2])                       #s=square,,,,m=margin,,,
x=np.array([1,2,3,4,5])                      #-.=dash,dott
plt.plot(y,'s-.m',ms=25)
plt.show()

# %%
y=np.array([5,6,9,12,2])
x=np.array([1,2,3,4,5])
plt.plot(y,'s-.m',ms=25,lw=5)
plt.show()

# %%
y=np.array([5,6,9,12,2])
x=np.array([1,2,3,4,5])
plt.plot(y,'s-.m',ms=25,lw=5,color='k')
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_9600\3667126914.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "s-.m" (-> color='m'). The keyword argument will take precedence.
#   plt.plot(y,'s-.m',ms=25,lw=5,color='k')

# %%
y=np.array([3,8,1,10])
plt.plot(y,marker='o',ms=20)
plt.show()

# %%
y=np.array([3,8,1,10,5,9,12])
plt.plot(y,marker='o',ms=20, mfc='r')         #mfc=marker face color
plt.show()

# %%
y=np.array([3,8,1,10,5,9,12])
plt.plot(y,marker='o',ms=20, mfc='r',mec='k')    #mec=marker edge color
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,color='r')
plt.show()

# %%
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1,'s:m',color='r',marker='s',ms=20)
plt.plot(y2,'o-.m',color='k',marker='o',ms=20)
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_9600\2973962741.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s:m" (-> marker='s'). The keyword argument will take precedence.
#   plt.plot(y1,'s:m',color='r',marker='s',ms=20)
# C:\Users\akash\AppData\Local\Temp\ipykernel_9600\2973962741.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "s:m" (-> color='m'). The keyword argument will take precedence.
#   plt.plot(y1,'s:m',color='r',marker='s',ms=20)
# C:\Users\akash\AppData\Local\Temp\ipykernel_9600\2973962741.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-.m" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(y2,'o-.m',color='k',marker='o',ms=20)
# ...

# %%
#Lebels
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# #set font property & position the title

# %%
#set font property & position the title

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])


font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.title("Sports Watch Data", fontdict = font1,loc="left")
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.plot(x,y)
plt.show()

# %%
#add grid lines to the plot
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis="x")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis="y")

plt.show()

# %%
#subplot
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#MATPLOTLIB SCATTER PLOT

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.title("13 cars passing",loc="left")
plt.xlabel("how old the car")
plt.ylabel("speed of the car")
plt.scatter(x,y)
plt.show()

# %%
#draw two plot on the same figure
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color="black")

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color="red")

plt.show()

# %%
#set a specific color for each dot...
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange",
                   "purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x,y, c=colors)
plt.show()

# %%
#colorMap..
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x,y, c=colors, cmap="viridis")
plt.colorbar()
plt.show()

# %%
#Sizes and transparency..
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y= np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x,y, s=sizes, alpha=0.5)
plt.show()

# %%
#combine color size and alpha
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
#MATPLOTLIB BARS
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]

plt.bar(x, y)
plt.show()

# %%
#horizontal bars
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y,height=0.1)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red", width= 0.1)
plt.show()

# %%
#MATPLOTLIB HISTOGRAM
x=np.random.normal(170,10,250)

plt.hist(x)
plt.show()

# %%
#MATPLOTLIB PIE CHARTS

y=([35,25,25,15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y,labels=mylabels, startangle=90)
plt.show()

# %%
#Explode
y=([35,25,25,15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode=[0.2,0,0,0]

plt.pie(y,labels=mylabels, explode=myexplode)
plt.show()

# %%
#Shadows
y=([35,25,25,15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode=[0.2,0,0,0]

plt.pie(y,labels=mylabels, explode=myexplode, shadow=True)
plt.show()

# %%
#colors

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#legend--to add a list of explanation for each wedge..
#legend with header
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title="Four Fruits:")
plt.show()

# %%
#homework
stud={
    "student":["akash","vicky","badal","ritesh","karan"],
    "Bcs2year_marks":[150,180,220,290,260],
    "Bcs1year_marks":[250,270,280,200,150],
    "Bcs3year_marks":[200,230,260,240,280]
}

# %%
 df=pd.DataFrame(stud)
df
# Out:
#   student  Bcs2year_marks  Bcs1year_marks  Bcs3year_marks
# 0   akash             150             250             200
# 1   vicky             180             270             230
# 2   badal             220             280             260
# 3  ritesh             290             200             240
# 4   karan             260             150             280

# %%
import plotly.express as px

# %%
df=px.line(stud,x="student",y="Bcs1year_marks")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9600\1968557006.py in <module>
# ----> 1 df=px.line(stud,x="student",y="Bcs1year_marks")
#       2 df
#
# NameError: name 'px' is not defined

# %%
x=np.array(["akash","vicky","badal","ritesh","karan"])
y=np.array([150,180,220,290,260])
plt.plot(x,y,"s:m",ms=25,color="r")
plt.title("Students_marks")
plt.xlabel("Students")
plt.ylabel("Bcs1year_marks")
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_17416\3050945421.py:3: UserWarning:
#
# color is redundantly defined by the 'color' keyword argument and the fmt string "s:m" (-> color='m'). The keyword argument will take precedence.

# %%
x=np.array(["akash","vicky","badal","ritesh","karan"])
y=np.array([150,180,220,290,260])
plt.bar(x,y,color="r")
plt.title("Students_marks")
plt.xlabel("Students")
plt.ylabel("Bcs1year_marks")
plt.show()

# %%
x=np.array(["akash","vicky","badal","ritesh","karan"])
y=np.array([150,180,220,290,260])
plt.scatter(x,y,color="r")
plt.title("Students_marks")
plt.xlabel("Students")
plt.ylabel("Bcs1year_marks")
plt.show()

# %%
y=np.array([150,180,220,290,260])
mylabel=["akash","vicky","badal","ritesh","karan"]

plt.pie(y, labels=mylabel)
plt.legend(title='Five Students:')
plt.show()

# %%
x=np.random.normal(150,180,220)

plt.hist(x)
plt.show()
