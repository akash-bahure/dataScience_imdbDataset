# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\akash\\OneDrive\\Documents\\imdb\\imdb_top_1000.csv")

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A      142
# 1               The Godfather          1972           A      175
# 2             The Dark Knight          2008          UA      152
# ...

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A      142
# 1             The Godfather          1972           A      175
# 2           The Dark Knight          2008          UA      152
# 3    The Godfather: Part II          1974           A      202
# 4              12 Angry Men          1957           U       96
#
#                       Genre  IMDB_Rating  \
# 0                     Drama          9.3
# 1            Crime    Drama          9.2
# 2  Action    Crime    Drama          9.0
# 3            Crime    Drama          9.0
# 4            Crime    Drama          9.0
#
# ...

# %%
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A      115
# 996                   Giant          1956           G      201
# 997   From Here to Eternity          1953      Passed      118
# 998                Lifeboat          1944         NaN       97
# 999            The 39 Steps          1935         NaN       86
#
#                             Genre  IMDB_Rating  \
# 995    Comedy    Drama    Romance          7.6
# 996              Drama    Western          7.6
# 997       Drama    Romance    War          7.6
# 998                  Drama    War          7.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   int64
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 125.1+ KB

# %%
df.describe()
# Out:
#            Runtime  IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  1000.000000  843.000000  1.000000e+03
# mean    122.891000     7.949300   77.971530  2.736929e+05
# std      28.093671     0.275491   12.376099  3.273727e+05
# min      45.000000     7.600000   28.000000  2.508800e+04
# 25%     103.000000     7.700000   70.000000  5.552625e+04
# 50%     119.000000     7.900000   79.000000  1.385485e+05
# 75%     137.000000     8.100000   87.000000  3.741612e+05
# max     321.000000     9.300000  100.000000  2.343110e+06

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime            int64
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
df.shape
# Out:
# (1000, 16)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["IMDB_Rating"].head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.0
# 3    9.0
# 4    9.0
# Name: IMDB_Rating, dtype: float64

# %%
type(df["IMDB_Rating"])
# Out:
# pandas.core.series.Series

# %%
df["IMDB_Rating"].shape
# Out:
# (1000,)

# %%
imdb=df[["Series_Title","Certificate"]]

# %%
imdb.head()
# Out:
#                Series_Title Certificate
# 0  The Shawshank Redemption           A
# 1             The Godfather           A
# 2           The Dark Knight          UA
# 3    The Godfather: Part II           A
# 4              12 Angry Men           U

# %%
df["IMDB_Rating"].max()
# Out:
# 9.3

# %%
df["IMDB_Rating"].min()
# Out:
# 7.6

# %%
df["IMDB_Rating"].count()
# Out:
# 1000

# %%
df.isnull()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 995        False         False          False        False    False  False
# 996        False         False          False        False    False  False
# 997        False         False          False        False    False  False
# 998        False         False          False         True    False  False
# 999        False         False          False         True    False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
#DATA CLEANING

# %%
max_metascore =df['Meta_score'].mean()

# %%
df.Meta_score.fillna(max_metascore,inplace=True)

# %%
df["Meta_score"].mean()
# Out:
# 77.9715302491102

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score         0
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df["Certificate"].value_counts()
# Out:
# U           234
# A           197
# UA          175
# R           146
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# 16            1
# TV-MA         1
# Unrated       1
# U/A           1
# Name: Certificate, dtype: int64

# %%
df.loc[:,["Star1","Star2"]].head()
# Out:
#             Star1           Star2
# 0     Tim Robbins  Morgan Freeman
# 1   Marlon Brando       Al Pacino
# 2  Christian Bale    Heath Ledger
# 3       Al Pacino  Robert De Niro
# 4     Henry Fonda     Lee J. Cobb

# %%
df.loc[:,"Series_Title"].head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# Name: Series_Title, dtype: object

# %%
df[(df.Genre=="Drama") & (df.IMDB_Rating==8) &(df.Certificate=="UA")]
# Out:
#                                            Poster_Link      Series_Title  \
# 347  https://m.media-amazon.com/images/M/MV5BMTM5OT...          The Help
# 352  https://m.media-amazon.com/images/M/MV5BMTUyMT...   My Name Is Khan
# 398  https://m.media-amazon.com/images/M/MV5BZTM3Zj...  Scent of a Woman
# 423  https://m.media-amazon.com/images/M/MV5BODFlYz...    Il conformista
#
#     Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# 347          2011          UA      146  Drama          8.0
# 352          2010          UA      165  Drama          8.0
# 398          1992          UA      156  Drama          8.0
# 423          1970          UA      113  Drama          8.0
#
#                                               Overview  Meta_score  \
# 347  An aspiring author during the civil rights mov...        62.0
# 352  An Indian Muslim man with Asperger's syndrome ...        50.0
# 398  A prep school student needing money agrees to ...        59.0
# ...

# %%
df[(df.Genre=="Comedy") & (df.Certificate=="G")]
# Out:
#                                            Poster_Link    Series_Title  \
# 855  https://m.media-amazon.com/images/M/MV5BZDVhNz...  The Odd Couple
#
#     Released_Year Certificate  Runtime   Genre  IMDB_Rating  \
# 855          1968           G      105  Comedy          7.7
#
#                                               Overview  Meta_score   Director  \
# 855  Two friends try sharing an apartment    but th...        86.0  Gene Saks
#
#            Star1           Star2         Star3         Star4  No_of_Votes  \
# 855  Jack Lemmon  Walter Matthau  John Fiedler  Herb Edelman        31572
#
#            Gross
# 855  4,45,27,234

# %%
df.groupby(["Certificate"])["Series_Title"].count()
# Out:
# Certificate
# 16            1
# A           197
# Approved     11
# G            12
# GP            2
# PG           37
# PG-13        43
# Passed       34
# R           146
# TV-14         1
# TV-MA         1
# TV-PG         3
# U           234
# U/A           1
# UA          175
# Unrated       1
# Name: Series_Title, dtype: int64

# %%
df["Series_Title"].shape
# Out:
# (1000,)

# %%
df["Series_Title"].unique().shape
# Out:
# (999,)

# %%
df.sort_values(by="Runtime",ascending=True).head(20)
# Out:
#                                            Poster_Link  \
# 194  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 567  https://m.media-amazon.com/images/M/MV5BMjMyYj...
# 320  https://m.media-amazon.com/images/M/MV5BYmRiMD...
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 717  https://m.media-amazon.com/images/M/MV5BYmYxZG...
# 719  https://m.media-amazon.com/images/M/MV5BMTQ0Nj...
# 920  https://m.media-amazon.com/images/M/MV5BMjEzMj...
# 876  https://m.media-amazon.com/images/M/MV5BYjllMm...
# 694  https://m.media-amazon.com/images/M/MV5BYjhhMD...
# 318  https://m.media-amazon.com/images/M/MV5BM2QwYW...
# 462  https://m.media-amazon.com/images/M/MV5BMTEyMT...
# 716  https://m.media-amazon.com/images/M/MV5BOTUzMz...
# 395  https://m.media-amazon.com/images/M/MV5BNWE4OT...
# 665  https://m.media-amazon.com/images/M/MV5BYTRiMW...
# 321  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# ...

# %%
df[["IMDB_Rating","Series_Title"]].groupby("IMDB_Rating").count().plot(kind="bar")

plt.xlabel("IMDB RATING",color="r")
plt.ylabel("Count Series Title",color="r")
plt.show()

# %%
df[["Gross","Released_Year"]].groupby("Gross").count().plot(kind="line")
# Out:
# <AxesSubplot:xlabel='Gross'>

# %%
sns.pairplot(df)
plt.show()

# %%
print(df["IMDB_Rating"].unique())
print(df["IMDB_Rating"].value_counts())
df["IMDB_Rating"].value_counts().plot()
# Out:
# [9.3 9.2 9.  8.9 8.8 8.7 8.6 8.5 8.4 8.3 8.2 8.1 8.  7.9 7.8 7.7 7.6]
# 7.7    157
# 7.8    151
# 8.0    141
# 8.1    127
# 7.6    123
# 7.9    106
# 8.2     67
# 8.3     44
# 8.4     31
# 8.5     20
# 8.6     15
# 8.7      5
# 8.8      5
# 8.9      3
# 9.0      3
# 9.2      1
# 9.3      1
# Name: IMDB_Rating, dtype: int64
# <AxesSubplot:>

# %%
df.Genre.value_counts().plot.pie(autopct="%.0f%%",figsize=(12,12),pctdistance=0.8,
                                              wedgeprops=dict(width=0.4))
plt.show()

# %%
dir_counts = df['Director'].value_counts()[:20]
plt.figure(figsize=(12,6))
sns.barplot(y=dir_counts.index,x=dir_counts.values)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A      142
# 1               The Godfather          1972           A      175
# 2             The Dark Knight          2008          UA      152
# ...

# %%
Genre_counts=df.groupby('Genre')['Series_Title'].count()

# %%
plt.bar(Genre_counts.index,Genre_counts.values)[:20]
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13900\1726389643.py in <module>
# ----> 1 plt.scatter(df)["Gross"],df["Meta_score"]
#
# TypeError: scatter() missing 1 required positional argument: 'y'
